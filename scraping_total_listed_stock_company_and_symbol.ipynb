# %%
//*[@id="company-list"]/table
//*[@id="company-list"]/table/tbody
//*[@id="company-list"]/table/tbody/tr[1]
//*[@id="company-list"]/table/tbody/tr[2]
//*[@id="company-list"]/table/tbody/tr[3]

//*[@id="company-list"]/table/tbody/tr[3]/td[1]
# Out:
#   File "<ipython-input-1-c356e64d3411>", line 1
#     //*[@id="company-list"]/table
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import  pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import matplotlib.pyplot as plt

PATH="chromedriver.exe"
driver =webdriver.Chrome(PATH)
time.sleep(2.4)

website='http://www.nepalstock.com/company'
driver.get(website)
time.sleep(2.4)

# %%
rows=len(driver.find_elements_by_xpath("//*[@id='company-list']/table/tbody/tr"))
columns=len(driver.find_elements_by_xpath('//*[@id="company-list"]/table/tbody/tr[3]/td'))

# %%
data=[]
for i in range(3,rows):
    row=[]
    for j in range(3,columns):
        value=driver.find_element_by_xpath('//*[@id="company-list"]/table/tbody/tr['+str(i)+']/td['+str(j)+']')
        row.append(value.text)
    data.append(row)

# %%
df = pd.DataFrame(data, columns = ['Stock Name', 'Stock Symbol','Sector'])

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                                             Stock Name Stock Symbol  \
# 0                              10 % NMB DEBENTURE 2085     NMBD2085
# 1                    10% Himalayan Bank Debenture 2083       HBLD83
# 2                        10% Laxmi Bank Debenture 2086       LBLD86
# 3                             10% Nabil Debenture 2082       NBLD82
# 4                    10% Nepal SBI Bank Debenture 2086      SBIBD86
# 5                       10% Prabhu Bank Debenture 2084       PBLD84
# 6                           10% Sunrise Debenture 2080        SRD80
# 7                  10.25% Citizens Bank Debenture 2086      CIZBD86
# 8        10.25% GLOBAL IME BANK LTD. DEBENTURE 2080/81     GBD80/81
# 9                            10.25% KBL Debenture 2086       KBLD86
# 10            10.25% Machhapuchhre Bank Debenture 2085     MBLD2085
# 11                          10.25% NBBL Debenture 2085     NBBD2085
# 12                   10.25% NIC Asia Debenture 2083/84    NICD83/84
# ...

# %%
df.to_csv('total_listed_stock.csv',index=False)
