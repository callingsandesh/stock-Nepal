# %%
import pandas as pd

# %%
import os

# %%
APP_FOLDER = 'C:/Users/lfc/Desktop/data_science/nepalStock/datasets/price'
arr = os.listdir(APP_FOLDER)

# %%
total_date=arr.index('2014-12-31.csv')

# %%
dates=arr[:total_date+1]

# %%
dates[0]
# Out:
# '2010-05-09.csv'

# %%
data=pd.read_csv("datasets/price/"+str(dates[4]))

# %%
for i in range(len(dates)):
    print(dates[i])
# Out:
# 2010-05-09.csv
# 2010-05-10.csv
# 2010-05-11.csv
# 2010-05-12.csv
# 2010-05-13.csv
# 2010-05-16.csv
# 2010-05-17.csv
# 2010-05-18.csv
# 2010-05-19.csv
# 2010-05-20.csv
# 2010-05-23.csv
# 2010-05-24.csv
# 2010-05-25.csv
# 2010-05-26.csv
# 2010-05-30.csv
# 2010-05-31.csv
# 2010-06-01.csv
# 2010-06-02.csv
# 2010-06-03.csv
# 2010-06-06.csv
# 2010-06-07.csv
# 2010-06-08.csv
# 2010-06-09.csv
# 2010-06-10.csv
# 2010-06-13.csv
# 2010-06-14.csv
# 2010-06-15.csv
# 2010-06-16.csv
# 2010-06-17.csv
# 2010-06-20.csv
# 2010-06-21.csv
# 2010-06-22.csv
# 2010-06-23.csv
# 2010-06-24.csv
# 2010-06-28.csv
# 2010-06-29.csv
# 2010-06-30.csv
# 2010-07-01.csv
# 2010-07-04.csv
# 2010-07-05.csv
# 2010-07-06.csv
# 2010-07-07.csv
# 2010-07-08.csv
# 2010-07-11.csv
# 2010-07-12.csv
# 2010-07-13.csv
# 2010-07-14.csv
# 2010-07-15.csv
# 2010-07-18.csv
# 2010-07-19.csv
# 2010-07-20.csv
# 2010-07-21.csv
# 2010-07-22.csv
# 2010-07-25.csv
# 2010-07-26.csv
# 2010-07-27.csv
# 2010-07-28.csv
# 2010-07-29.csv
# ...

# %%
for j in range(len(dates)):
    data=pd.read_csv("datasets/price/"+str(dates[j]))
    for i in range(len(data)):
        data.Date[i]=dates[j].replace(".csv","")
        data.Date=pd.to_datetime(data.Date)
        data.to_csv('corrected_dates/'+str(dates[j]), index=False)
# Out:
# <ipython-input-59-d208b4574af3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Date[i]=dates[j].replace(".csv","")

# %%
data
# Out:
#           Date                                  Traded Companies Stock Symbol  \
# 0   2010-05-09                         Ace Development Bank Ltd.          NaN
# 1   2010-05-09                               Api Finance Limited          NaN
# 2   2010-05-09       Arun Valley Hydropower Development Co. Ltd.         AHPC
# 3   2010-05-09                     Axis Development Bank Limited          NaN
# 4   2010-05-09                            Bank of Kathmandu Ltd.         BOKL
# 5   2010-05-09          Business Universal Development Bank Ltd.          NaN
# 6   2010-05-09                Chilime Hydropower Company Limited         CHCL
# 7   2010-05-09                Citizen Bank International Limited        CZBIL
# 8   2010-05-09                          Citizen Investment Trust          NaN
# 9   2010-05-09             Clean Energy Development Bank Limited          NaN
# 10  2010-05-09                              Crystal Finance Ltd.          CFL
# ...

# %%
for i in range(len(dates)):
    print(dates[i].replace(".csv",""))
